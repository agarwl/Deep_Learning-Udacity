# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
import cPickle as pickle

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'anarchism', 'a', 'as', 'term', 'of', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.995476
# Nearest to this: flurry, contained, spaced, nugget, puppies, och, electrode, sais,
# Nearest to these: mountaineers, editors, bop, negatively, encyclopedia, unravel, rosario, ecstasy,
# Nearest to the: bitter, materialists, hymen, manual, quran, skynyrd, syntactic, flemish,
# Nearest to d: figure, assortment, greenblatt, lies, haymarket, candles, numeral, hopped,
# Nearest to used: frontispiece, droughts, cries, bored, perfecti, soyuz, beau, abjads,
# Nearest to can: clitic, nacht, because, fuzes, ark, dunkeld, plagiarized, outlying,
# Nearest to i: zamora, nihon, liquidity, durham, lk, insistence, apostate, memories,
# Nearest to its: alves, pinning, advocates, assistance, disappearances, onerous, give, airforce,
# Nearest to th: socialized, tests, pier, glimpse, auld, generality, bodies, facial,
# Nearest to only: separators, luk, dane, singers, hymnody, archdiocese, vaccinium, ua,
# Nearest to new: tigris, madrid, rbi, speculated, newer, stifling, hirschfeld, pest,
# Nearest to b: semigroup, shows, parcel, domesticated, accumulations, epicurean, misnomer, including,
# Nearest to was: gorgon, pir, aswan, responding, acquired, spoke, incensed, cottages,
# Nearest to about: isa, snails, hedonist, bluffs, berthe, cranial, disguise, ebenezer,
# Nearest to all: collector, wracked, swampy, eruptions, kronstadt, encounter, arbor, birding,
# Nearest to but: statehood, goalscorer, elaborate, counterrevolutionary, conjectures, taxa, wolfhound, corollary,
# Average loss at step 2000: 4.358742
# Average loss at step 4000: 3.863903
# Average loss at step 6000: 3.786415
# Average loss at step 8000: 3.679845
# Average loss at step 10000: 3.611789
# Nearest to this: it, the, his, a, which, luzon, aristophanes, any,
# Nearest to these: guinness, both, rosario, harem, drang, takers, such, burke,
# Nearest to the: a, this, its, his, their, each, eu, an,
# Nearest to d: jornal, figure, saves, b, numismatics, numeral, adherent, haemophilia,
# Nearest to used: known, playstation, dogma, wallenberg, recompense, meander, bilaterally, handy,
# Nearest to can: would, may, thy, should, are, ark, is, kowloon,
# Nearest to i: tleilaxu, metcalfe, nihon, experimentation, disintegrated, basalt, mitral, zamora,
# Nearest to its: his, the, their, romanorum, pairing, escap, a, lineage,
# Nearest to th: four, three, six, socialized, seven, hosting, tests, five,
# Nearest to only: separators, sang, hymnody, inwards, osvaldo, dip, foregoing, archdiocese,
# Nearest to new: madrid, regular, tigris, beneficiary, pest, myth, arabidopsis, rbi,
# Nearest to b: domesticated, d, including, allotrope, carcassonne, replayed, phodopus, hammond,
# Nearest to was: is, has, by, pir, were, be, became, been,
# Nearest to about: isa, jd, ebenezer, hedonist, instruction, banded, rucker, hitchhikers,
# Nearest to all: form, other, unsound, approximately, wracked, collector, hugh, mourners,
# Nearest to but: obeying, did, and, efron, are, jumbled, is, shermer,
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-01669d5c739a> in <module>()
#       9       batch_size, num_skips, skip_window)
#      10     feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
# ---> 11     _, l = session.run([optimizer, loss], feed_dict=feed_dict)
#      12     average_loss += l
#      13     if step % 2000 == 0:
#
# /home/rishabh/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     370     try:
#     371       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 372                          run_metadata_ptr)
#     373       if run_metadata:
#     374         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/rishabh/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     634     try:
#     635       results = self._do_run(handle, target_list, unique_fetches,
# --> 636                              feed_dict_string, options, run_metadata)
#     637     finally:
#     638       # The movers are no longer used. Delete them.
#
# /home/rishabh/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#     706     if handle is None:
#     707       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 708                            target_list, options, run_metadata)
#     709     else:
#     710       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/rishabh/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#     713   def _do_call(self, fn, *args):
#     714     try:
# --> 715       return fn(*args)
#     716     except errors.OpError as e:
#     717       message = compat.as_text(e.message)
#
# /home/rishabh/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#     695         return tf_session.TF_Run(session, options,
#     696                                  feed_dict, fetch_list, target_list,
# --> 697                                  status, run_metadata)
#     698
#     699     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
with open('embeddings.p','wb') as f:
      pickle.dump(final_embeddings,f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
final_embeddings = pickle.load(open('embeddings.p','rb')) 
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch_cbow(batch_size, skip_window):
  global data_index
  context_window = 2 * skip_window
  assert batch_size % context_window == 0 # ensure the context window can be taken from the batch size
  num_labels = batch_size // context_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(num_labels, 1), dtype=np.int32)
  span = context_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(num_labels):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    labels[i, 0] = buffer[skip_window]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] =  buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(labels.shape[0])])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of']
#     labels: ['originated', 'as', 'a', 'term']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['originated', 'term', 'a', 'anarchism', 'originated', 'term', 'as', 'of']
#     labels: ['as', 'a']

# %%
# seq_ids only needs to be generated once so do this as a numpy array rather than a tensor.
def generate_seq_ids(batch_size,context_window):
    seq_ids = np.zeros(batch_size, dtype=np.int32)
    cur_id = -1
    for i in range(batch_size):
        if i % context_window == 0:
          cur_id = cur_id + 1
        seq_ids[i] = cur_id
    return seq_ids

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(xrange(valid_window), valid_size))
num_sampled = 32 # Number of negative examples to sample.

## General defines
context_window = 2 * skip_window
num_labels = batch_size // context_window
seq_ids = generate_seq_ids(batch_size,context_window)

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[num_labels, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # seq_ids only needs to be generated once so do this as a numpy array rather than a tensor.
  
  # use segment_sum to add together the related words and reduce the output to be num_labels in size.
  final_embed = tf.segment_sum(embed, seq_ids)
  
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, final_embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in xrange(num_steps):
    batch_data, batch_labels = generate_batch_cbow(batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = "Nearest to %s:" % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = "%s %s," % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.087351
# Nearest to some: ornithologist, undisturbed, locks, oral, crossings, whimsical, importer, methodius,
# Nearest to when: philanthropy, stud, clade, honeydew, cockburn, josiah, fascinating, derive,
# Nearest to UNK: croatia, lomo, adolf, nowhere, oneself, tacitus, suzaku, ability,
# Nearest to one: yad, dracula, municipal, mute, leipzig, epi, anabaptism, deeds,
# Nearest to states: ordinary, energetics, gylfaginning, bayezid, lute, wim, bray, puppet,
# Nearest to over: briefs, aerobic, kibaki, estrada, emmer, solzhenitsyn, offender, reinterpretation,
# Nearest to or: vesalius, generously, ventris, changeover, rea, impressive, massless, mengele,
# Nearest to if: dispatched, gray, bonfires, spectrometry, hypopituitarism, priceless, typeface, homeworld,
# Nearest to history: anointing, edith, slept, constructive, richards, snack, magick, marlowe,
# Nearest to from: beja, provincia, su, scripts, ocular, plectrum, curiosities, idris,
# Nearest to d: negotiators, gale, breton, tabulation, collaborator, rollin, intercity, arc,
# Nearest to so: sundays, franz, ono, dassault, wcw, sourceforge, boz, prohibits,
# Nearest to than: inertia, mahendra, continent, symbol, abdulaziz, himalayan, keitel, detergents,
# Nearest to a: halide, imagination, brumaire, spee, luria, thr, rebadged, haggai,
# Nearest to into: zak, refuges, dal, hagar, truk, loa, dirkjan, attu,
# Nearest to known: chili, wrest, uga, jules, immigrants, patricio, paltrow, reprinting,
# Average loss at step 2000: 3.592382
# Average loss at step 4000: 2.975753
# Average loss at step 6000: 3.009560
# Average loss at step 8000: 2.896037
# Average loss at step 10000: 2.820157
# Nearest to some: many, these, several, all, enough, each, other, most,
# Nearest to when: inverse, microstates, iarc, mcmanus, kamakura, translating, where, bastiat,
# Nearest to UNK: envoys, princes, freescale, trinity, psychiatric, unconventional, sarcophagus, pesticide,
# Nearest to one: two, nine, eight, six, seven, four, zero, five,
# Nearest to states: usurpers, tana, energetics, bayezid, bray, goofy, hispanic, demeanor,
# Nearest to over: schedules, ensuing, from, schell, fluctuating, farewell, delivers, reelected,
# Nearest to or: fewest, uefa, and, horned, butler, amplifies, unduly, dryness,
# Nearest to if: gray, dustin, though, glorious, childress, hawk, priceless, unwilling,
# Nearest to history: mathfrak, battle, slept, circulating, splinter, presumption, british, trending,
# Nearest to from: between, into, parisians, by, brussels, maeterlinck, kills, agena,
# Nearest to d: b, guderian, breton, viscosity, ethnography, ni, mallarm, offensive,
# Nearest to so: ono, kun, unbiased, impartial, encoder, sayfawa, linguistique, sheridan,
# Nearest to than: appendix, pfc, keitel, accents, resorting, punter, guideline, with,
# Nearest to a: the, ange, kern, rethinking, risks, perennially, scumm, consolidation,
# Nearest to into: from, swords, hello, on, elephant, paleocene, at, zak,
# Nearest to known: well, such, far, used, horta, paltrow, zorro, edessa,
# Average loss at step 12000: 2.752720
# Average loss at step 14000: 2.783582
# Average loss at step 16000: 2.692651
# Average loss at step 18000: 2.777309
# Average loss at step 20000: 2.638584
# Nearest to some: many, these, wrong, those, their, all, various, any,
# Nearest to when: if, where, before, while, but, after, iarc, morel,
# Nearest to UNK: family, vivid, approx, azteca, hebrew, p, unto, maynooth,
# Nearest to one: seven, two, six, eight, three, four, nine, five,
# Nearest to states: hispanic, concede, goofy, holiday, prayers, kingdom, jason, oghuz,
# Nearest to over: delivers, sole, from, through, ensuing, aluminum, schell, shrub,
# Nearest to or: fossilization, and, superpowered, than, mazda, cleef, nationally, per,
# Nearest to if: when, where, guthrie, showed, childress, could, morel, say,
# Nearest to history: eidyn, dose, simplified, homonyms, splinter, grieving, form, trending,
# Nearest to from: into, in, waking, over, capsule, hover, gravis, odie,
# Nearest to d: b, c, factually, ni, dojos, ghq, francesco, malone,
# Nearest to so: constantly, dop, mistrust, more, boyz, lvaro, mashiach, too,
# Nearest to than: monsignor, pfc, or, eyepiece, physiologically, lash, much, appendix,
# Nearest to a: z, no, any, jamal, overrule, ange, demokratische, euboea,
# Nearest to into: from, hello, through, catacomb, composing, kingston, swords, elephant,
# Nearest to known: used, such, well, dismissed, zorro, defined, toolbars, lateral,
# Average loss at step 22000: 2.682950
# Average loss at step 24000: 2.404169
# Average loss at step 26000: 2.645499
# Average loss at step 28000: 2.559338
# Average loss at step 30000: 2.583477
# Nearest to some: many, these, several, each, any, trajectories, those, both,
# Nearest to when: if, where, before, after, because, could, since, however,
# Nearest to UNK: cram, rolled, spectrometers, sandinistas, donation, stefan, zaghawa, folds,
# Nearest to one: two, seven, three, five, nine, eight, four, six,
# Nearest to states: hispanic, nations, goofy, prayers, namath, kingdom, asterisk, concede,
# Nearest to over: zuma, pancake, visits, fatima, sincerity, clan, out, malfunction,
# Nearest to or: and, somatic, writes, beneficiaries, purports, extrinsic, shyness, darcy,
# Nearest to if: when, where, after, guthrie, dean, could, showed, above,
# Nearest to history: list, fraction, dose, translations, form, eidyn, cortex, issa,
# Nearest to from: into, through, waking, between, su, shoot, agena, parisians,
# Nearest to d: b, dojos, ni, c, ghq, e, cavitation, factually,
# Nearest to so: too, monde, mashiach, brp, scandinavians, abigail, emphasis, humanly,
# Nearest to than: modes, fart, physiologically, lash, becoming, monsignor, discredit, accents,
# Nearest to a: the, no, any, possum, ange, sleek, this, compostela,
# Nearest to into: through, from, during, attu, swords, exceeds, elephant, endeavored,
# Nearest to known: such, possible, used, well, defined, regarded, considered, ket,
# Average loss at step 32000: 2.556327
# Average loss at step 34000: 2.495340
# Average loss at step 36000: 2.499665
# Average loss at step 38000: 2.476879
# Average loss at step 40000: 2.496449
# Nearest to some: many, several, their, any, those, these, most, various,
# Nearest to when: if, where, before, while, though, because, after, although,
# Nearest to UNK: reaper, j, octal, charles, dictate, de, granary, atrophy,
# Nearest to one: eight, seven, two, five, six, nine, three, four,
# Nearest to states: nations, kingdom, goofy, xiv, unilaterally, argue, concede, prayers,
# Nearest to over: through, fatima, pancake, fulk, misinterpretation, about, off, scriptura,
# Nearest to or: and, than, crimea, hashing, tokens, bassoons, nav, extract,
# Nearest to if: when, although, where, after, though, unless, follows, thus,
# Nearest to history: whence, list, chicxulub, dose, creator, collection, bardot, ovarian,
# Nearest to from: through, into, after, across, among, agena, between, within,
# Nearest to d: b, dojos, ni, biruni, booker, cavitation, p, g,
# Nearest to so: too, then, emphasis, necklace, contended, fredericton, brp, cleef,
# Nearest to than: much, or, physiologically, far, lash, addictions, temperature, modes,
# Nearest to a: another, the, weiner, no, every, somali, ange, quite,
# Nearest to into: through, from, towards, along, between, within, away, kingston,
# Nearest to known: such, used, regarded, defined, possible, considered, well, described,
# Average loss at step 42000: 2.523900
# Average loss at step 44000: 2.483878
# Average loss at step 46000: 2.491139
# Average loss at step 48000: 2.407502
# Average loss at step 50000: 2.109673
# Nearest to some: many, several, those, various, certain, most, bro, these,
# Nearest to when: if, where, after, although, before, during, though, enforceable,
# Nearest to UNK: ka, tulare, menzies, san, cadres, suitcase, grote, bavaria,
# Nearest to one: two, seven, nine, five, four, three, eight, six,
# Nearest to states: nations, kingdom, countries, biotite, notches, islands, circassians, unilaterally,
# Nearest to over: about, kampaku, clan, arecibo, watchtower, summarizing, aron, slater,
# Nearest to or: and, superpowered, blinds, minesweeper, outrageous, peripatetic, spelt, procopius,
# Nearest to if: when, where, before, though, unless, since, mongoloids, jewell,
# Nearest to history: list, eidyn, harden, dose, rink, version, form, lojban,
# Nearest to from: through, into, agena, ap, within, receded, during, after,
# Nearest to d: b, dojos, gale, francesco, biruni, robert, thera, ni,
# Nearest to so: then, thus, contended, casein, emphasis, cleef, transactional, goggles,
# Nearest to than: physiologically, far, much, appendix, peyton, receive, addictions, lash,
# Nearest to a: crediting, ange, sleek, another, perennially, parallelism, gf, rethinking,
# Nearest to into: through, from, along, under, towards, between, away, within,
# Nearest to known: regarded, used, such, referred, defined, considered, seen, possible,
# Average loss at step 52000: 2.476537
# Average loss at step 54000: 2.409691
# Average loss at step 56000: 2.407878
# Average loss at step 58000: 2.450879
# Average loss at step 60000: 2.387427
# Nearest to some: many, various, several, any, foundered, certain, most, all,
# Nearest to when: although, however, after, before, though, until, if, where,
# Nearest to UNK: leo, ins, dumb, polysaccharides, et, baguirmi, colons, genoese,
# Nearest to one: eight, five, six, three, nine, four, seven, two,
# Nearest to states: kingdom, nations, state, xiv, mailing, countries, androgens, notches,
# Nearest to over: within, around, fatima, across, nextstep, pancake, safeguard, meister,
# Nearest to or: and, than, while, cohorts, superpowered, transsexual, licensee, punchline,
# Nearest to if: jewell, since, when, though, without, where, badgers, mongoloids,
# Nearest to history: list, creator, collection, science, consisting, version, ovarian, encyclopedia,
# Nearest to from: through, between, into, within, before, parisians, across, hermeneutics,
# Nearest to d: b, dojos, downturn, luis, hohenstaufen, factually, thera, bahasa,
# Nearest to so: too, contended, anmen, how, cleef, less, emphasis, flared,
# Nearest to than: or, much, modes, tether, crater, peyton, aleph, appendix,
# Nearest to a: the, every, any, another, possum, ange, this, mithraic,
# Nearest to into: towards, through, within, under, between, from, megabits, with,
# Nearest to known: regarded, used, seen, defined, possible, referred, such, considered,
# Average loss at step 62000: 2.373447
# Average loss at step 64000: 2.396501
# Average loss at step 66000: 2.391418
# Average loss at step 68000: 2.416276
# Average loss at step 70000: 2.442080
# Nearest to some: many, several, certain, any, these, bro, various, numerous,
# Nearest to when: if, before, though, although, while, after, cobra, danes,
# Nearest to UNK: rockers, betty, dorothy, marie, chassis, erwin, alloy, gif,
# Nearest to one: four, six, two, eight, nine, five, seven, three,
# Nearest to states: kingdom, nations, us, countries, state, xiv, notches, fra,
# Nearest to over: within, across, duddy, around, transformative, miniszt, ariadne, into,
# Nearest to or: and, outrageous, alfaro, although, superpowered, niva, signatory, rudd,
# Nearest to if: when, though, jewell, mongoloids, where, ordinal, since, before,
# Nearest to history: creator, hispaniola, view, origin, version, list, eidyn, zines,
# Nearest to from: into, within, ap, before, through, during, maeterlinck, in,
# Nearest to d: b, downturn, thera, francesco, luis, p, el, mathrm,
# Nearest to so: contended, too, rationing, fante, cleef, implies, skilling, resonate,
# Nearest to than: physiologically, vj, pfc, much, crater, peyton, footnote, auchinleck,
# Nearest to a: the, consciously, isdn, your, cohn, chloride, monterey, hitomaro,
# Nearest to into: through, within, from, towards, along, across, off, filkers,
# Nearest to known: used, defined, regarded, possible, seen, such, described, referred,
# Average loss at step 72000: 2.411495
# Average loss at step 74000: 2.344630
# Average loss at step 76000: 2.370576
# Average loss at step 78000: 2.362549
# Average loss at step 80000: 2.274066
# Nearest to some: many, several, this, certain, these, any, various, bro,
# Nearest to when: while, if, after, though, before, during, although, then,
# Nearest to UNK: santiago, webmaster, garibaldi, vulpes, neverwinter, ashcroft, del, russification,
# Nearest to one: eight, two, six, nine, three, five, seven, four,
# Nearest to states: nations, kingdom, countries, us, cities, islands, fadh, agencies,
# Nearest to over: duddy, around, within, transformative, measuring, histone, chamorros, isca,
# Nearest to or: and, though, superpowered, mellitus, horowitz, nicobar, cysteine, than,
# Nearest to if: when, after, jewell, though, before, because, hungarians, mongoloids,
# Nearest to history: list, creator, eidyn, collection, consisting, making, development, hispaniola,
# Nearest to from: through, within, turquoise, into, under, before, during, between,
# Nearest to d: jerry, sharper, santer, rd, george, alan, b, tenzin,
# Nearest to so: sometimes, thus, oceanography, simply, then, too, transactional, now,
# Nearest to than: physiologically, pfc, licensee, vj, peyton, footnote, bankrupted, orinoco,
# Nearest to a: the, possum, sleek, euros, another, lough, hammett, any,
# Nearest to into: through, within, across, off, along, around, from, under,
# Nearest to known: used, such, possible, regarded, described, referred, seen, considered,
# Average loss at step 82000: 2.311657
# Average loss at step 84000: 2.278430
# Average loss at step 86000: 2.325568
# Average loss at step 88000: 2.346500
# Average loss at step 90000: 2.301428
# Nearest to some: many, several, any, numerous, most, various, these, certain,
# Nearest to when: if, after, while, though, although, before, where, until,
# Nearest to UNK: rerum, biennial, senator, sullivan, andalus, parker, truffaut, shakespeare,
# Nearest to one: two, five, three, six, seven, foal, eight, kal,
# Nearest to states: kingdom, nations, us, uni, pannonia, agencies, events, countries,
# Nearest to over: around, across, histone, within, duddy, off, between, nn,
# Nearest to or: and, bytecode, cloaca, crayfish, niva, halogen, mellitus, welcomes,
# Nearest to if: when, though, before, without, after, imo, mongoloids, then,
# Nearest to history: list, creator, university, eidyn, origin, hispaniola, transcontinental, ibo,
# Nearest to from: within, into, through, under, at, across, turquoise, africans,
# Nearest to d: b, cavitation, dojos, hohenstaufen, teen, haddock, ni, cabral,
# Nearest to so: then, too, eventually, thus, emphasis, oceanography, massacred, grammaticus,
# Nearest to than: licensee, peyton, physiologically, modes, pfc, tether, eyepiece, even,
# Nearest to a: another, the, blonde, ange, possum, perennially, divergences, cohn,
# Nearest to into: towards, through, from, within, across, in, onto, filkers,
# Nearest to known: possible, defined, regarded, described, such, seen, used, opposed,
# Average loss at step 92000: 2.297491
# Average loss at step 94000: 2.374215
# Average loss at step 96000: 2.274828
# Average loss at step 98000: 2.104943
# Average loss at step 100000: 2.269834
# Nearest to some: many, several, certain, this, numerous, those, all, various,
# Nearest to when: after, though, before, while, if, ideographic, appleseed, once,
# Nearest to UNK: shambles, fewest, l, judicious, malley, cadmium, ndez, renouf,
# Nearest to one: two, four, five, six, three, seventy, yes, nine,
# Nearest to states: nations, state, kingdom, countries, pannonia, particles, strains, processes,
# Nearest to over: around, across, duddy, within, about, between, into, apotheosis,
# Nearest to or: and, kossuth, electro, bytecode, brosnan, superpowered, mellitus, chem,
# Nearest to if: when, then, cannot, though, badgers, where, so, before,
# Nearest to history: creator, list, collection, nature, science, transcontinental, development, aldosterone,
# Nearest to from: into, across, between, through, within, antiwar, rassemblement, in,
# Nearest to d: b, p, cavitation, nesmith, ni, alan, hohenstaufen, warrior,
# Nearest to so: too, believe, how, suppose, kummer, if, contended, feel,
# Nearest to than: but, sectional, modes, peyton, kitab, physiologically, addictions, realaudio,
# Nearest to a: the, another, possum, perennially, this, euros, funneled, every,
# Nearest to into: through, towards, across, onto, from, within, toward, under,
# Nearest to known: possible, used, defined, described, referred, such, understood, regarded,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
